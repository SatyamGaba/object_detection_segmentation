# %%
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
losses = np.load("./Segmentation/ch/train_epoch_loss.npy")
accuracies = np.load("./Segmentation/ch/train_epoch_accuracy.npy")
print(losses.shape, accuracies.shape)

val_losses = np.load("./Segmentation/ch/val_epoch_loss.npy")
val_accuracies = np.load("./Segmentation/ch/val_epoch_accuracy.npy")
print(val_losses.shape, val_accuracies.shape)

file_name = "cos_casia"
# Out:
# (7,) (7,)
# (6,) (6,)

# %%
# data = accuracies
# val_data = val_accuracies
data = losses
val_data = val_losses
# epochs = np.arange(1,data.shape[0]+1,1)/23

# %%
plt.title("Accuracy Curve for Cos Face on CASIA-Webface Dataset")
plt.xlabel("Number of Iterations")
plt.ylabel("Accuracy")
plt.plot(data, color='r', label='Training Accuracy')
plt.plot(val_data, color='b', label='Validation Accuracy')

plt.grid(True)
plt.legend()
# plt.savefig("./Segmentation/results/%s_acc.png"%file_name)
plt.show()
